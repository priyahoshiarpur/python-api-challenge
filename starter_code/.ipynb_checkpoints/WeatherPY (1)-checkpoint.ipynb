# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %%
# URL for GET requests to retrieve city data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# List for holding reponse information
lon = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lat = []
date = []
country = []
cloudiness = []

# Loop through the list of cities and request for data on each
print("Beginning Data Retrieval")
print("-------------------------------------")
count = 0
set = 1
for index, city in enumerate(cities):
    count = count + 1
    # To avoid api call rate limits, get city weather data in sets of 50 cities,
    # with 5 seconds sleep time, and then continue
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("-------------------------------------")
print("Data Retrieval Complete")
print("-------------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 2 of Set 1 | qaqortoq
# City not found. Skipping...
# Processing Record 3 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 4 of Set 1 | kapa'a
# City not found. Skipping...
# Processing Record 5 of Set 1 | yagry
# City not found. Skipping...
# Processing Record 6 of Set 1 | mbeni
# City not found. Skipping...
# Processing Record 7 of Set 1 | utrik
# City not found. Skipping...
# Processing Record 8 of Set 1 | ciudad acuna
# City not found. Skipping...
# Processing Record 9 of Set 1 | kavaratti
# City not found. Skipping...
# Processing Record 10 of Set 1 | troitsko-pechorsk
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 12 of Set 1 | ola
# City not found. Skipping...
# Processing Record 13 of Set 1 | hamilton
# City not found. Skipping...
# Processing Record 14 of Set 1 | igarka
# City not found. Skipping...
# Processing Record 15 of Set 1 | olonkinbyen
# City not found. Skipping...
# Processing Record 16 of Set 1 | nagarpur
# City not found. Skipping...
# Processing Record 17 of Set 1 | ta`u
# City not found. Skipping...
# Processing Record 18 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 19 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 20 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 21 of Set 1 | anadyr
# City not found. Skipping...
# Processing Record 22 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 23 of Set 1 | kuanda
# City not found. Skipping...
# Processing Record 24 of Set 1 | mermoz boabab
# City not found. Skipping...
# Processing Record 25 of Set 1 | bilibino
# City not found. Skipping...
# Processing Record 26 of Set 1 | cable beach
# City not found. Skipping...
# Processing Record 27 of Set 1 | hawaiian paradise park
# City not found. Skipping...
# Processing Record 28 of Set 1 | isafjordur
# City not found. Skipping...
# Processing Record 29 of Set 1 | dame-marie
# City not found. Skipping...
# Processing Record 30 of Set 1 | san agustin de valle fertil
# City not found. Skipping...
# Processing Record 31 of Set 1 | dwarka
# City not found. Skipping...
# Processing Record 32 of Set 1 | atafu village
# City not found. Skipping...
# Processing Record 33 of Set 1 | ak"yar
# City not found. Skipping...
# Processing Record 34 of Set 1 | fortuna
# City not found. Skipping...
# Processing Record 35 of Set 1 | puerto natales
# City not found. Skipping...
# Processing Record 36 of Set 1 | kourou
# City not found. Skipping...
# Processing Record 37 of Set 1 | tobruk
# City not found. Skipping...
# Processing Record 38 of Set 1 | fale old settlement
# City not found. Skipping...
# Processing Record 39 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 40 of Set 1 | atkarsk
# City not found. Skipping...
# Processing Record 41 of Set 1 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 42 of Set 1 | malters
# City not found. Skipping...
# Processing Record 43 of Set 1 | albany
# City not found. Skipping...
# Processing Record 44 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 46 of Set 1 | cockburn town
# City not found. Skipping...
# Processing Record 47 of Set 1 | oppdal
# City not found. Skipping...
# Processing Record 48 of Set 1 | west island
# City not found. Skipping...
# Processing Record 49 of Set 1 | baijiantan
# City not found. Skipping...
# Processing Record 50 of Set 1 | lata
# City not found. Skipping...
# Processing Record 1 of Set 2 | iqaluit
# City not found. Skipping...
# Processing Record 2 of Set 2 | wichita falls
# City not found. Skipping...
# Processing Record 3 of Set 2 | yamazakicho-nakabirose
# City not found. Skipping...
# Processing Record 4 of Set 2 | port lincoln
# City not found. Skipping...
# Processing Record 5 of Set 2 | crane
# City not found. Skipping...
# Processing Record 6 of Set 2 | owen sound
# City not found. Skipping...
# Processing Record 7 of Set 2 | rio grande
# City not found. Skipping...
# Processing Record 8 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 2 | stanley
# City not found. Skipping...
# Processing Record 10 of Set 2 | port douglas
# City not found. Skipping...
# Processing Record 11 of Set 2 | brisas de zicatela
# City not found. Skipping...
# Processing Record 12 of Set 2 | le francois
# City not found. Skipping...
# Processing Record 13 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 2 | port mathurin
# City not found. Skipping...
# Processing Record 15 of Set 2 | kalianget
# City not found. Skipping...
# Processing Record 16 of Set 2 | maricopa
# City not found. Skipping...
# Processing Record 17 of Set 2 | sidi akkacha
# City not found. Skipping...
# Processing Record 18 of Set 2 | praia da vitoria
# City not found. Skipping...
# Processing Record 19 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 20 of Set 2 | tura
# City not found. Skipping...
# Processing Record 21 of Set 2 | howard springs
# City not found. Skipping...
# Processing Record 22 of Set 2 | smithers
# City not found. Skipping...
# Processing Record 23 of Set 2 | xining
# City not found. Skipping...
# Processing Record 24 of Set 2 | al bayda'
# City not found. Skipping...
# Processing Record 25 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 26 of Set 2 | alofi
# City not found. Skipping...
# Processing Record 27 of Set 2 | salinopolis
# City not found. Skipping...
# Processing Record 28 of Set 2 | serdar
# City not found. Skipping...
# Processing Record 29 of Set 2 | ilulissat
# City not found. Skipping...
# Processing Record 30 of Set 2 | bethel
# City not found. Skipping...
# Processing Record 31 of Set 2 | abrantes
# City not found. Skipping...
# Processing Record 32 of Set 2 | tolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | blackmans bay
# City not found. Skipping...
# Processing Record 34 of Set 2 | margaret river
# City not found. Skipping...
# Processing Record 35 of Set 2 | tarauaca
# City not found. Skipping...
# Processing Record 36 of Set 2 | weno
# City not found. Skipping...
# Processing Record 37 of Set 2 | tatvan
# City not found. Skipping...
# Processing Record 38 of Set 2 | aykhal
# City not found. Skipping...
# Processing Record 39 of Set 2 | thompson
# City not found. Skipping...
# Processing Record 40 of Set 2 | ancud
# City not found. Skipping...
# Processing Record 41 of Set 2 | bongaree
# City not found. Skipping...
# Processing Record 42 of Set 2 | gadzhiyevo
# City not found. Skipping...
# Processing Record 43 of Set 2 | bardai
# City not found. Skipping...
# Processing Record 44 of Set 2 | touros
# City not found. Skipping...
# Processing Record 45 of Set 2 | farah
# City not found. Skipping...
# Processing Record 46 of Set 2 | tralee
# City not found. Skipping...
# Processing Record 47 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 2 | andrychow
# City not found. Skipping...
# Processing Record 49 of Set 2 | klyuchi
# City not found. Skipping...
# Processing Record 50 of Set 2 | visegrad
# City not found. Skipping...
# Processing Record 1 of Set 3 | markovo
# City not found. Skipping...
# Processing Record 2 of Set 3 | kerikeri
# City not found. Skipping...
# Processing Record 3 of Set 3 | constantia
# City not found. Skipping...
# Processing Record 4 of Set 3 | nar'yan-mar
# City not found. Skipping...
# Processing Record 5 of Set 3 | waitangi
# City not found. Skipping...
# Processing Record 6 of Set 3 | susuman
# City not found. Skipping...
# Processing Record 7 of Set 3 | uturoa
# City not found. Skipping...
# Processing Record 8 of Set 3 | noosa heads
# City not found. Skipping...
# Processing Record 9 of Set 3 | nemuro
# City not found. Skipping...
# Processing Record 10 of Set 3 | kenora
# City not found. Skipping...
# Processing Record 11 of Set 3 | tazacorte
# City not found. Skipping...
# Processing Record 12 of Set 3 | puerto colombia
# City not found. Skipping...
# Processing Record 13 of Set 3 | ulladulla
# City not found. Skipping...
# Processing Record 14 of Set 3 | badger
# City not found. Skipping...
# Processing Record 15 of Set 3 | yellowknife
# City not found. Skipping...
# Processing Record 16 of Set 3 | luckau
# City not found. Skipping...
# Processing Record 17 of Set 3 | waingapu
# City not found. Skipping...
# Processing Record 18 of Set 3 | hobyo
# City not found. Skipping...
# Processing Record 19 of Set 3 | jayapura
# City not found. Skipping...
# Processing Record 20 of Set 3 | faya-largeau
# City not found. Skipping...
# Processing Record 21 of Set 3 | celestun
# City not found. Skipping...
# Processing Record 22 of Set 3 | pingliang
# City not found. Skipping...
# Processing Record 23 of Set 3 | gumdag
# City not found. Skipping...
# Processing Record 24 of Set 3 | labuan bajo
# City not found. Skipping...
# Processing Record 25 of Set 3 | vila franca do campo
# City not found. Skipping...
# Processing Record 26 of Set 3 | lupane
# City not found. Skipping...
# Processing Record 27 of Set 3 | wailua homesteads
# City not found. Skipping...
# Processing Record 28 of Set 3 | sultanah
# City not found. Skipping...
# Processing Record 29 of Set 3 | suva
# City not found. Skipping...
# Processing Record 30 of Set 3 | mao
# City not found. Skipping...
# Processing Record 31 of Set 3 | jamestown
# City not found. Skipping...
# Processing Record 32 of Set 3 | brookings
# City not found. Skipping...
# Processing Record 33 of Set 3 | choibalsan
# City not found. Skipping...
# Processing Record 34 of Set 3 | natal
# City not found. Skipping...
# Processing Record 35 of Set 3 | papatowai
# City not found. Skipping...
# Processing Record 36 of Set 3 | cambria
# City not found. Skipping...
# Processing Record 37 of Set 3 | invercargill
# City not found. Skipping...
# Processing Record 38 of Set 3 | luderitz
# City not found. Skipping...
# Processing Record 39 of Set 3 | urangan
# City not found. Skipping...
# Processing Record 40 of Set 3 | ust-nera
# City not found. Skipping...
# Processing Record 41 of Set 3 | barro alto
# City not found. Skipping...
# Processing Record 42 of Set 3 | lebu
# City not found. Skipping...
# Processing Record 43 of Set 3 | hanzhong
# City not found. Skipping...
# Processing Record 44 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 45 of Set 3 | sitka
# City not found. Skipping...
# Processing Record 46 of Set 3 | tommot
# City not found. Skipping...
# Processing Record 47 of Set 3 | al burayqah
# City not found. Skipping...
# Processing Record 48 of Set 3 | nema
# City not found. Skipping...
# Processing Record 49 of Set 3 | chake chake
# City not found. Skipping...
# Processing Record 50 of Set 3 | murrells inlet
# City not found. Skipping...
# Processing Record 1 of Set 4 | mount pearl
# City not found. Skipping...
# Processing Record 2 of Set 4 | udachny
# City not found. Skipping...
# Processing Record 3 of Set 4 | masuda
# City not found. Skipping...
# Processing Record 4 of Set 4 | pimentel
# City not found. Skipping...
# Processing Record 5 of Set 4 | enewetak
# City not found. Skipping...
# Processing Record 6 of Set 4 | longyearbyen
# City not found. Skipping...
# Processing Record 7 of Set 4 | kidal
# City not found. Skipping...
# Processing Record 8 of Set 4 | westport
# City not found. Skipping...
# Processing Record 9 of Set 4 | fort mcmurray
# City not found. Skipping...
# Processing Record 10 of Set 4 | amga
# City not found. Skipping...
# Processing Record 11 of Set 4 | malango
# City not found. Skipping...
# Processing Record 12 of Set 4 | afaahiti
# City not found. Skipping...
# Processing Record 13 of Set 4 | whitehorse
# City not found. Skipping...
# Processing Record 14 of Set 4 | avarua
# City not found. Skipping...
# Processing Record 15 of Set 4 | nogliki
# City not found. Skipping...
# Processing Record 16 of Set 4 | hami
# City not found. Skipping...
# Processing Record 17 of Set 4 | okhotsk
# City not found. Skipping...
# Processing Record 18 of Set 4 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 19 of Set 4 | castillos
# City not found. Skipping...
# Processing Record 20 of Set 4 | abalak
# City not found. Skipping...
# Processing Record 21 of Set 4 | vernon
# City not found. Skipping...
# Processing Record 22 of Set 4 | dakhla
# City not found. Skipping...
# Processing Record 23 of Set 4 | port saint john's
# City not found. Skipping...
# Processing Record 24 of Set 4 | prince rupert
# City not found. Skipping...
# Processing Record 25 of Set 4 | tromso
# City not found. Skipping...
# Processing Record 26 of Set 4 | santiago
# City not found. Skipping...
# Processing Record 27 of Set 4 | mount gambier
# City not found. Skipping...
# Processing Record 28 of Set 4 | kokopo
# City not found. Skipping...
# Processing Record 29 of Set 4 | kachug
# City not found. Skipping...
# Processing Record 30 of Set 4 | saint-pierre
# City not found. Skipping...
# Processing Record 31 of Set 4 | eastlake
# City not found. Skipping...
# Processing Record 32 of Set 4 | chaplynka
# City not found. Skipping...
# Processing Record 33 of Set 4 | lompoc
# City not found. Skipping...
# Processing Record 34 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 35 of Set 4 | chui
# City not found. Skipping...
# Processing Record 36 of Set 4 | banjar
# City not found. Skipping...
# Processing Record 37 of Set 4 | dudinka
# City not found. Skipping...
# Processing Record 38 of Set 4 | teknaf
# City not found. Skipping...
# Processing Record 39 of Set 4 | iskateley
# City not found. Skipping...
# Processing Record 40 of Set 4 | gebeit
# City not found. Skipping...
# Processing Record 41 of Set 4 | minas
# City not found. Skipping...
# Processing Record 42 of Set 4 | ati
# City not found. Skipping...
# Processing Record 43 of Set 4 | ribeira grande
# City not found. Skipping...
# Processing Record 44 of Set 4 | ginir
# City not found. Skipping...
# Processing Record 45 of Set 4 | georgetown
# City not found. Skipping...
# Processing Record 46 of Set 4 | paragominas
# City not found. Skipping...
# Processing Record 47 of Set 4 | andreyevo
# City not found. Skipping...
# Processing Record 48 of Set 4 | la passe
# City not found. Skipping...
# Processing Record 49 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 50 of Set 4 | margate
# City not found. Skipping...
# Processing Record 1 of Set 5 | didouche mourad
# City not found. Skipping...
# Processing Record 2 of Set 5 | san patricio
# City not found. Skipping...
# Processing Record 3 of Set 5 | novaya ladoga
# City not found. Skipping...
# Processing Record 4 of Set 5 | egilsstadir
# City not found. Skipping...
# Processing Record 5 of Set 5 | aasiaat
# City not found. Skipping...
# Processing Record 6 of Set 5 | fort bragg
# City not found. Skipping...
# Processing Record 7 of Set 5 | gweru
# City not found. Skipping...
# Processing Record 8 of Set 5 | manga
# City not found. Skipping...
# Processing Record 9 of Set 5 | tazovsky
# City not found. Skipping...
# Processing Record 10 of Set 5 | dickinson
# City not found. Skipping...
# Processing Record 11 of Set 5 | newman
# City not found. Skipping...
# Processing Record 12 of Set 5 | college
# City not found. Skipping...
# Processing Record 13 of Set 5 | kirensk
# City not found. Skipping...
# Processing Record 14 of Set 5 | haiku-pauwela
# City not found. Skipping...
# Processing Record 15 of Set 5 | marsala
# City not found. Skipping...
# Processing Record 16 of Set 5 | talnakh
# City not found. Skipping...
# Processing Record 17 of Set 5 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 18 of Set 5 | itoman
# City not found. Skipping...
# Processing Record 19 of Set 5 | vohipaho
# City not found. Skipping...
# Processing Record 20 of Set 5 | targuist
# City not found. Skipping...
# Processing Record 21 of Set 5 | hermanus
# City not found. Skipping...
# Processing Record 22 of Set 5 | aginskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | vorgashor
# City not found. Skipping...
# Processing Record 24 of Set 5 | bathsheba
# City not found. Skipping...
# Processing Record 25 of Set 5 | kingscliff
# City not found. Skipping...
# Processing Record 26 of Set 5 | almunecar
# City not found. Skipping...
# Processing Record 27 of Set 5 | changji
# City not found. Skipping...
# Processing Record 28 of Set 5 | baise city
# City not found. Skipping...
# Processing Record 29 of Set 5 | phongsali
# City not found. Skipping...
# Processing Record 30 of Set 5 | port hedland
# City not found. Skipping...
# Processing Record 31 of Set 5 | san pedro
# City not found. Skipping...
# Processing Record 32 of Set 5 | mwinilunga
# City not found. Skipping...
# Processing Record 33 of Set 5 | saudarkrokur
# City not found. Skipping...
# Processing Record 34 of Set 5 | christchurch
# City not found. Skipping...
# Processing Record 35 of Set 5 | karratha
# City not found. Skipping...
# Processing Record 36 of Set 5 | naze
# City not found. Skipping...
# Processing Record 37 of Set 5 | lower sackville
# City not found. Skipping...
# Processing Record 38 of Set 5 | kodiak
# City not found. Skipping...
# Processing Record 39 of Set 5 | kalawit
# City not found. Skipping...
# Processing Record 40 of Set 5 | trapani
# City not found. Skipping...
# Processing Record 41 of Set 5 | namtsy
# City not found. Skipping...
# Processing Record 42 of Set 5 | zeya
# City not found. Skipping...
# Processing Record 43 of Set 5 | sao joao da barra
# City not found. Skipping...
# Processing Record 44 of Set 5 | sheopur
# City not found. Skipping...
# Processing Record 45 of Set 5 | xinyuan
# City not found. Skipping...
# Processing Record 46 of Set 5 | merizo village
# City not found. Skipping...
# Processing Record 47 of Set 5 | nanakuli
# City not found. Skipping...
# Processing Record 48 of Set 5 | ewo
# City not found. Skipping...
# Processing Record 49 of Set 5 | st. john's
# City not found. Skipping...
# Processing Record 50 of Set 5 | cueibet
# City not found. Skipping...
# Processing Record 1 of Set 6 | chonchi
# City not found. Skipping...
# Processing Record 2 of Set 6 | peterhead
# City not found. Skipping...
# Processing Record 3 of Set 6 | zheleznogorsk-ilimskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | kodinsk
# City not found. Skipping...
# Processing Record 5 of Set 6 | naugachhia
# City not found. Skipping...
# Processing Record 6 of Set 6 | flying fish cove
# City not found. Skipping...
# Processing Record 7 of Set 6 | broome
# City not found. Skipping...
# Processing Record 8 of Set 6 | remire-montjoly
# City not found. Skipping...
# Processing Record 9 of Set 6 | al 'alamayn
# City not found. Skipping...
# Processing Record 10 of Set 6 | yangambi
# City not found. Skipping...
# Processing Record 11 of Set 6 | hithadhoo
# City not found. Skipping...
# Processing Record 12 of Set 6 | polyarnyy
# City not found. Skipping...
# Processing Record 13 of Set 6 | port elizabeth
# City not found. Skipping...
# Processing Record 14 of Set 6 | lake havasu city
# City not found. Skipping...
# Processing Record 15 of Set 6 | sariveliler
# City not found. Skipping...
# Processing Record 16 of Set 6 | amalapuram
# City not found. Skipping...
# Processing Record 17 of Set 6 | batang
# City not found. Skipping...
# Processing Record 18 of Set 6 | bonthe
# City not found. Skipping...
# Processing Record 19 of Set 6 | katabu
# City not found. Skipping...
# Processing Record 20 of Set 6 | khandyga
# City not found. Skipping...
# Processing Record 21 of Set 6 | santa ana
# City not found. Skipping...
# Processing Record 22 of Set 6 | city of isabela
# City not found. Skipping...
# Processing Record 23 of Set 6 | lihue
# City not found. Skipping...
# Processing Record 24 of Set 6 | zavety il'icha
# City not found. Skipping...
# Processing Record 25 of Set 6 | cabo san lucas
# City not found. Skipping...
# Processing Record 26 of Set 6 | pucheng
# City not found. Skipping...
# Processing Record 27 of Set 6 | goshainganj
# City not found. Skipping...
# Processing Record 28 of Set 6 | kapit
# City not found. Skipping...
# Processing Record 29 of Set 6 | baruun-urt
# City not found. Skipping...
# Processing Record 30 of Set 6 | sao vicente
# City not found. Skipping...
# Processing Record 31 of Set 6 | neustrelitz
# City not found. Skipping...
# Processing Record 32 of Set 6 | shenjiamen
# City not found. Skipping...
# Processing Record 33 of Set 6 | baoro
# City not found. Skipping...
# Processing Record 34 of Set 6 | mezgor'e
# City not found. Skipping...
# Processing Record 35 of Set 6 | mejit
# City not found. Skipping...
# Processing Record 36 of Set 6 | shimoda
# City not found. Skipping...
# Processing Record 37 of Set 6 | mumford
# City not found. Skipping...
# Processing Record 38 of Set 6 | quillota
# City not found. Skipping...
# Processing Record 39 of Set 6 | solnechnyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | vadso
# City not found. Skipping...
# Processing Record 41 of Set 6 | san antonio de pale
# City not found. Skipping...
# Processing Record 42 of Set 6 | gryfino
# City not found. Skipping...
# Processing Record 43 of Set 6 | guarapari
# City not found. Skipping...
# Processing Record 44 of Set 6 | kratie
# City not found. Skipping...
# Processing Record 45 of Set 6 | parang
# City not found. Skipping...
# Processing Record 46 of Set 6 | grafton
# City not found. Skipping...
# Processing Record 47 of Set 6 | bonanza
# City not found. Skipping...
# Processing Record 48 of Set 6 | randers
# City not found. Skipping...
# Processing Record 49 of Set 6 | sisimiut
# City not found. Skipping...
# Processing Record 50 of Set 6 | lionel town
# City not found. Skipping...
# Processing Record 1 of Set 7 | lazarevskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | otavalo
# City not found. Skipping...
# Processing Record 3 of Set 7 | bandar lampung
# City not found. Skipping...
# Processing Record 4 of Set 7 | huarmey
# City not found. Skipping...
# Processing Record 5 of Set 7 | inhambane
# City not found. Skipping...
# Processing Record 6 of Set 7 | gap
# City not found. Skipping...
# Processing Record 7 of Set 7 | kurumkan
# City not found. Skipping...
# Processing Record 8 of Set 7 | lugovoy
# City not found. Skipping...
# Processing Record 9 of Set 7 | arkalyk
# City not found. Skipping...
# Processing Record 10 of Set 7 | kerman
# City not found. Skipping...
# Processing Record 11 of Set 7 | gilgit
# City not found. Skipping...
# Processing Record 12 of Set 7 | port macquarie
# City not found. Skipping...
# Processing Record 13 of Set 7 | angaur state
# City not found. Skipping...
# Processing Record 14 of Set 7 | waynesville
# City not found. Skipping...
# Processing Record 15 of Set 7 | sadao
# City not found. Skipping...
# Processing Record 16 of Set 7 | quepos
# City not found. Skipping...
# Processing Record 17 of Set 7 | yarkovo
# City not found. Skipping...
# Processing Record 18 of Set 7 | kyzylorda
# City not found. Skipping...
# Processing Record 19 of Set 7 | sassandra
# City not found. Skipping...
# Processing Record 20 of Set 7 | cidreira
# City not found. Skipping...
# Processing Record 21 of Set 7 | mancio lima
# City not found. Skipping...
# Processing Record 22 of Set 7 | felege neway
# City not found. Skipping...
# Processing Record 23 of Set 7 | sitangkai
# City not found. Skipping...
# Processing Record 24 of Set 7 | sedico
# City not found. Skipping...
# Processing Record 25 of Set 7 | porto novo
# City not found. Skipping...
# Processing Record 26 of Set 7 | raja
# City not found. Skipping...
# Processing Record 27 of Set 7 | esquina
# City not found. Skipping...
# Processing Record 28 of Set 7 | carbonear
# City not found. Skipping...
# Processing Record 29 of Set 7 | yuzhno-kurilsk
# City not found. Skipping...
# Processing Record 30 of Set 7 | rukban
# City not found. Skipping...
# Processing Record 31 of Set 7 | kashgar
# City not found. Skipping...
# Processing Record 32 of Set 7 | santa cruz
# City not found. Skipping...
# Processing Record 33 of Set 7 | maxixe
# City not found. Skipping...
# Processing Record 34 of Set 7 | gizo
# City not found. Skipping...
# Processing Record 35 of Set 7 | kingston
# City not found. Skipping...
# Processing Record 36 of Set 7 | sabya
# City not found. Skipping...
# Processing Record 37 of Set 7 | kitui
# City not found. Skipping...
# Processing Record 38 of Set 7 | usinsk
# City not found. Skipping...
# Processing Record 39 of Set 7 | saldanha
# City not found. Skipping...
# Processing Record 40 of Set 7 | hammerfest
# City not found. Skipping...
# Processing Record 41 of Set 7 | rodniki
# City not found. Skipping...
# Processing Record 42 of Set 7 | hirara
# City not found. Skipping...
# Processing Record 43 of Set 7 | mitu
# City not found. Skipping...
# Processing Record 44 of Set 7 | huntsville
# City not found. Skipping...
# Processing Record 45 of Set 7 | roschinskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | marsaskala
# City not found. Skipping...
# Processing Record 47 of Set 7 | phumi veal sre
# City not found. Skipping...
# Processing Record 48 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 49 of Set 7 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 50 of Set 7 | palmer
# City not found. Skipping...
# Processing Record 1 of Set 8 | coquimbo
# City not found. Skipping...
# Processing Record 2 of Set 8 | hadibu
# City not found. Skipping...
# Processing Record 3 of Set 8 | broken hill
# City not found. Skipping...
# Processing Record 4 of Set 8 | solnechnogorsk
# City not found. Skipping...
# Processing Record 5 of Set 8 | topeka
# City not found. Skipping...
# Processing Record 6 of Set 8 | suai
# City not found. Skipping...
# Processing Record 7 of Set 8 | kermit
# City not found. Skipping...
# Processing Record 8 of Set 8 | wotje
# City not found. Skipping...
# Processing Record 9 of Set 8 | moanda
# City not found. Skipping...
# Processing Record 10 of Set 8 | labytnangi
# City not found. Skipping...
# Processing Record 11 of Set 8 | shibirghan
# City not found. Skipping...
# Processing Record 12 of Set 8 | shalqar
# City not found. Skipping...
# Processing Record 13 of Set 8 | slawharad
# City not found. Skipping...
# Processing Record 14 of Set 8 | pala
# City not found. Skipping...
# Processing Record 15 of Set 8 | sidqabad
# City not found. Skipping...
# Processing Record 16 of Set 8 | aioun
# City not found. Skipping...
# Processing Record 17 of Set 8 | tevriz
# City not found. Skipping...
# Processing Record 18 of Set 8 | shenkursk
# City not found. Skipping...
# Processing Record 19 of Set 8 | abhayapuri
# City not found. Skipping...
# Processing Record 20 of Set 8 | saint-joseph
# City not found. Skipping...
# Processing Record 21 of Set 8 | thaba-tseka
# City not found. Skipping...
# Processing Record 22 of Set 8 | linden
# City not found. Skipping...
# Processing Record 23 of Set 8 | boa vista
# City not found. Skipping...
# Processing Record 24 of Set 8 | saipan

# %% [markdown]
# # Convert raw data to dataframe

# %%
cities_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
          })

# Drop any cities that were skipped because they could not return any response from OpenWeatherMap API.
cities_df = cities_df.dropna(how="any")

# Export the city data into a .csv file.
cities_df.to_csv("./output_data/cities.csv", index=False)

# Display the DataFrame
cities_df

# %%
cities_df["Humidity"].describe()

# %%
humidity_101 = cities_df[(cities_df["Humidity"] > 100)].index
humidity_101

# %%
clean_city_data = cities_df.drop(humidity_101, inplace=False)
clean_city_data

# %% [markdown]
# # Create the Scatter Plots Requested
# Latitude Vs. Temperature

# %%
date_now = datetime.date(datetime.now())

# Create a scatter plot for latitude vs max temperature.
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Max Temp"]

fig1, ax1 = plt.subplots(figsize=(11,8))
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.title(f"City Latitude vs Max Temperature {date_now}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save the figure
plt.savefig("./output_data/latitude_vs_max_temp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Latitude vs Humidity

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Humidity"]

fig1, ax1 = plt.subplots(figsize=(11, 8))
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity {date_now}")
plt.grid()

# Save the figure
plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Latitude vs Cloudiness

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Cloudiness"]

fig1, ax1 = plt.subplots(figsize=(10,8))
markersize=12
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness {date_now}")
plt.grid()

# Save the figure
plt.savefig("./output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Wind Speed"]

fig1, ax1 = plt.subplots(figsize=(10,8))
markersize=12
plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed {date_now}")
plt.grid()

# Save the figure
plt.savefig("./output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Linear Regression

# %%
# Create a function to create Linear Regression plots for remaining activities
def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere, text_coordinates, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Generate plots     
    fig1, ax1 = plt.subplots(figsize=(12,8))
    plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
    plt.plot(x_values,regress_values,"r-")
    date_now = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {date_now}",fontsize = 15)
    plt.xlabel(x_label,fontsize=14)
    plt.ylabel(y_label,fontsize=14)
    if ylim is not None:
        plt.ylim(0, ylim)
    plt.annotate(line_eq, text_coordinates, fontsize=20, color="red")
    
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_weather_df = clean_city_data.loc[clean_city_data["Lat"] >= 0]

northern_hemi_weather_df.head()
#southern_hemi_weather_df = clean_city_data.loc[clean_city_data["Lat"] < 0]

# %%
southern_hemi_weather_df = clean_city_data.loc[clean_city_data["Lat"] < 0]
southern_hemi_weather_df.head()

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemi_weather_df["Lat"]
y_values = northern_hemi_weather_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Northern", (10, 10))

# Save the figure
plt.savefig("./output_data/northern_hem_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Southerm hemisphere - Lat vs Max Temp

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemi_weather_df["Lat"]
y_values = southern_hemi_weather_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (-52, 75))

# Save the figure
plt.savefig("./output_data/southern_hem_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# *Discussion about the linear relationship: The correlation between latitude and maximum temperature is strong for both the hemispheres. It is higher for southern hemisphere (0.82), indicating that as we move away from the equator, the maximum temperature keeps dropping in a more linear manner.

# %% [markdown]
# # Northern hemisphere - Lat vs Humidity

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(50,50))
plt.savefig("./output_data/northern_hem_linear_lat_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Southern hemisphere - Lat vs Humidity

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(50, 50), 100)
plt.savefig("./output_data/southern_hem_linear_lat_vs_humudity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# There is no correlation between latitude and humidity for southern hemisphere (0.04). For northern hemisphere, it is the same case, expect for the higher latitudes.

# %% [markdown]
# # Northern hemisphere - Lat vs Cloudiness

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness (%)", "Northern", (20, 60))

plt.savefig("./output_data/northern_hem_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Southern hemisphere - Lat vs Cloudiness

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("./output_data/southern_hem_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# There is no correlation between latitude and cloudiness for both, southern and northern hemispheres. Both show scattered values all over the plots.

# %% [markdown]
# # Northern hemisphere - Lat vs Wind Speed

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("./output_data/northern_hem_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Southern hemisphere - Lat vs Wind Speed

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
plt.savefig("./output_data/southern_hem_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# The r-squared is:0.0016903124668836253
#
# The correlation between both factors is -0.04
#
# There is no correlation between latitude and wind speed either, for both hemispheres. Both show evenly scattered values over the latitudes.
